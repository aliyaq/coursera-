# %% [markdown]
# ## Applied Data Science Capstone project
#
# This notebook will be used to complete assigments in final stage of Applied data science cource on IBM platform.i will use this notebook to keep track of assigments required for cource completion as well as keep track of the overall progress in the subject.
#
# Week 1 assignment requires to create and share the notebook.
#
# First request is to load required libraries:

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
